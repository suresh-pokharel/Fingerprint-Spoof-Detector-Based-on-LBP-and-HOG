# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
img = cv.imread("C:\\Image_Analysis_CV\\Image_Analysis_CV\\images\\cat.jpg")
gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
sift = cv.SIFT_create()
kp = sift.detect(gray,None)
img=cv.drawKeypoints(gray,kp,img)
cv.imwrite('sift_keypoints.jpg',img)
plt.axis("off")
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-c8560789adbe> in <module>
#       3 import matplotlib.pyplot as plt
#       4 img = cv.imread("C:\\Image_Analysis_CV\\Image_Analysis_CV\\images\\cat.jpg")
# ----> 5 gray= cv.cvtColor(img,cv.COLOR_BGR2GRAY)
#       6 sift = cv.SIFT_create()
#       7 kp = sift.detect(gray,None)
#
# error: OpenCV(4.5.1) /tmp/pip-req-build-ms668fyv/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
img=cv.drawKeypoints(gray,kp,img,flags=cv.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
cv.imwrite('sift_keypoints.jpg',img)
plt.axis("off")
plt.imshow(img)

# %%
sift = cv.SIFT_create()
kp, des = sift.detectAndCompute(gray,None)
img=cv.drawKeypoints(gray,kp,img)
#cv.imwrite('sift_keypoints.jpg',img)
plt.axis("off")
plt.imshow(img)
